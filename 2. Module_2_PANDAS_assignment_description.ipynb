# %% [markdown]
# Download this data to use in the exercise:
#
# https://www.kaggle.com/the-guardian/olympic-games/data
#
# This exercise looks at data on all of the past olympics (up to 2014). Follow allong the text and use code cells to answer the questions.
#
# First, use UI or use the following code to initialize your backend and upload the datasets to colaboratory.

# %%
import pandas as pd
pd.options.display.max_rows = 200
# The following is code for uploading a file to the colab.research.google 
# environment.

# library for uploading files
from google.colab import files 

def upload_files():
    # initiates the upload - follow the dialogues that appear
    uploaded = files.upload()

    # verify the upload
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))

    # uploaded files need to be written to file to interact with them
    # as part of a file system
    for filename in uploaded.keys():
        with open(filename, 'wb') as f:
            f.write(uploaded[filename])

# %%
upload_files()
# Out:
#      <input type="file" id="files-a747c4ac-fe76-46d5-8fc6-db442b414f5c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a747c4ac-fe76-46d5-8fc6-db442b414f5c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-35-f037fe590c82> in <module>()
# ----> 1 upload_files()
#
# <ipython-input-34-cbf9d35ca7ad> in upload_files()
#       9 def upload_files():
#      10     # initiates the upload - follow the dialogues that appear
# ---> 11     uploaded = files.upload()
#      12
#      13     # verify the upload
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      70     result = _output.eval_js(
#      71         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# ---> 72             output_id=output_id))
#      73     if result['action'] != 'append':
#      74       # JS side uses a generator of promises to process all of the files- some
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# --> 106         raise MessageError(reply['error'])
#     107       return reply.get('data', None)
#     108
#
# MessageError: RangeError: Maximum call stack size exceeded.

# %% [markdown]
# ## Basics

# %% [markdown]
# 1) Load the three data files as DataFrames.

# %%
country_dict_df = pd.read_csv("dictionary.csv")
summer_df = pd.read_csv("summer.csv")
winter_df = pd.read_csv("winter.csv")

# %% [markdown]
# 2) Get a basic feel for the schemas of these three dataframes. Run some of the EDA techniques we discussed.

# %%
display(country_dict_df.head(10))
display(summer_df.head(10))
display(winter_df.head(10))
# Out:
#                Country Code  Population  GDP per Capita
# 0          Afghanistan  AFG  32526562.0      594.323081
# 1              Albania  ALB   2889167.0     3945.217582
# 2              Algeria  ALG  39666519.0     4206.031232
# 3      American Samoa*  ASA     55538.0             NaN
# 4              Andorra  AND     70473.0             NaN
# 5               Angola  ANG  25021974.0     4101.472152
# 6  Antigua and Barbuda  ANT     91818.0    13714.731962
# 7            Argentina  ARG  43416755.0    13431.878340
# 8              Armenia  ARM   3017712.0     3489.127690
# 9               Aruba*  ARU    103889.0             NaN
#    Year    City     Sport  ... Gender                       Event   Medal
# 0  1896  Athens  Aquatics  ...    Men              100M Freestyle    Gold
# 1  1896  Athens  Aquatics  ...    Men              100M Freestyle  Silver
# 2  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4  1896  Athens  Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# 5  1896  Athens  Aquatics  ...    Men             1200M Freestyle  Bronze
# 6  1896  Athens  Aquatics  ...    Men             1200M Freestyle    Gold
# 7  1896  Athens  Aquatics  ...    Men             1200M Freestyle  Silver
# 8  1896  Athens  Aquatics  ...    Men              400M Freestyle  Bronze
# 9  1896  Athens  Aquatics  ...    Men              400M Freestyle    Gold
#
# [10 rows x 9 columns]
#    Year      City     Sport Discipline  ... Country Gender            Event   Medal
# 0  1924  Chamonix  Biathlon   Biathlon  ...     FRA    Men  Military Patrol  Bronze
# 1  1924  Chamonix  Biathlon   Biathlon  ...     FRA    Men  Military Patrol  Bronze
# 2  1924  Chamonix  Biathlon   Biathlon  ...     FRA    Men  Military Patrol  Bronze
# 3  1924  Chamonix  Biathlon   Biathlon  ...     FRA    Men  Military Patrol  Bronze
# 4  1924  Chamonix  Biathlon   Biathlon  ...     SUI    Men  Military Patrol    Gold
# 5  1924  Chamonix  Biathlon   Biathlon  ...     SUI    Men  Military Patrol    Gold
# 6  1924  Chamonix  Biathlon   Biathlon  ...     SUI    Men  Military Patrol    Gold
# 7  1924  Chamonix  Biathlon   Biathlon  ...     SUI    Men  Military Patrol    Gold
# 8  1924  Chamonix  Biathlon   Biathlon  ...     FIN    Men  Military Patrol  Silver
# 9  1924  Chamonix  Biathlon   Biathlon  ...     FIN    Men  Military Patrol  Silver
#
# [10 rows x 9 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         201 non-null    object
#  1   Code            201 non-null    object
#  2   Population      196 non-null    float64
#  3   GDP per Capita  176 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 6.4+ KB

# %%
display(country_dict_df.info())
display(summer_df.info())
display(winter_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         201 non-null    object
#  1   Code            201 non-null    object
#  2   Population      196 non-null    float64
#  3   GDP per Capita  176 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 6.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5770 entries, 0 to 5769
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        5770 non-null   int64
#  1   City        5770 non-null   object
#  2   Sport       5770 non-null   object
#  3   Discipline  5770 non-null   object
#  4   Athlete     5770 non-null   object
#  5   Country     5770 non-null   object
#  6   Gender      5770 non-null   object
#  7   Event       5770 non-null   object
#  8   Medal       5770 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 405.8+ KB
# None

# %% [markdown]
# 3) The semantics of this data all looks pretty straight forward. Can we verify that the Population column is not a power of ten? Try querying for just the 'Canada' row in the country dictionary DataFrame to verify this.
#
# Tips:
# - use `.loc`
# - Look at the data!

# %%
#Canada Row query. Canada is row index number 34:

display(country_dict_df.loc[34,:])

print("\nCountry with largest population")


#country with largest population:
display(country_dict_df.sort_values('Population', ascending= False).iloc[0])
# Out:
# Country                Canada
# Code                      CAN
# Population        3.58518e+07
# GDP per Capita        43248.5
# Name: 34, dtype: object
# Country with largest population
# Country                 China
# Code                      CHN
# Population        1.37122e+09
# GDP per Capita        8027.68
# Name: 40, dtype: object

# %% [markdown]
# 4) Looking at just the Summer olympics let's do some querying. Every query here can be done in one line each:
#
# >a) Display the row corresponding to athlete Kate Walsh's medal.
#
# >b) Display just the City corresponding to athlete Kate Walsh's medal.
#
# >c) List each sport found in the summer olympics DataFrame
#
# >d) What medal did Cristian Gatu win in 1976?
#
# >e) How many medals have been won by USA and China cummulative? Hint: Use `.count()` after a query to count the rows.

# %%
kate_walsh = summer_df[summer_df['Athlete'] == "WALSH, Kate"]
kate_walsh
# Out:
#        Year    City   Sport Discipline  ... Country Gender   Event   Medal
# 30576  2012  London  Hockey     Hockey  ...     GBR  Women  Hockey  Bronze
#
# [1 rows x 9 columns]

# %%
 kate_walsh['City']
# Out:
# 30576    London
# Name: City, dtype: object

# %%
print(summer_df['Sport'].sort_values().unique())
# Out:
# ['Aquatics' 'Archery' 'Athletics' 'Badminton' 'Baseball' 'Basketball'
#  'Basque Pelota' 'Boxing' 'Canoe' 'Canoe / Kayak' 'Cricket' 'Croquet'
#  'Cycling' 'Equestrian' 'Fencing' 'Football' 'Golf' 'Gymnastics'
#  'Handball' 'Hockey' 'Ice Hockey' 'Jeu de paume' 'Judo' 'Lacrosse'
#  'Modern Pentathlon' 'Polo' 'Rackets' 'Roque' 'Rowing' 'Rugby' 'Sailing'
#  'Shooting' 'Skating' 'Softball' 'Table Tennis' 'Taekwondo' 'Tennis'
#  'Triathlon' 'Tug of War' 'Volleyball' 'Water Motorsports' 'Weightlifting'
#  'Wrestling']

# %% [markdown]
# TUG OF WAR was in Olympics????

# %%
summer_df[(summer_df['Athlete']=="GATU, Cristian") & (summer_df['Year'] == 1976)]['Medal']
# Out:
# 14691    Silver
# Name: Medal, dtype: object

# %%
country_dict_df[country_dict_df['Country'] == "China"]
# Out:
#    Country Code    Population  GDP per Capita
# 40   China  CHN  1.371220e+09      8027.68381

# %%
print(summer_df[(summer_df['Country'] == 'CHN') | (summer_df['Country'] == 'USA') ]['Medal'].count())
# Out:
# 5392

# %% [markdown]
# 5) Let's do some sorting! I want you to make two DataFrame variables:
#
#
# *   Sort the country dictionary by Population from lowest to highest
# *   Sort the country dictionary by population from highest to lowest
#
# Make sure you save the results of each sort to a variable.
#
# Next, call `.reset_index(drop=True)` on each of the new variables you created. What has this done?
#
# Finally, we are interested in know the country name with the largest population and the country name with the
# smallest population. Fortunately, the data structures we just created lend themselves nicely to this task. Query
# for the Country name in the first row of each of DataFrames you created in this question. (hint: Use `.at[,]`)

# %%
population_ascending = country_dict_df.sort_values('Population', ascending = True)
population_ascending.head(5)
# Out:
#                     Country Code  Population  GDP per Capita
# 127                   Nauru  NRU     10222.0     9827.544281
# 138                   Palau  PLW     21291.0    13498.661406
# 27   British Virgin Islands  IVB     30117.0             NaN
# 156              San Marino  SMR     31781.0             NaN
# 106           Liechtenstein  LIE     37531.0             NaN

# %%
population_descending = country_dict_df.sort_values('Population', ascending = False)
population_descending.head(5)
# Out:
#            Country Code    Population  GDP per Capita
# 40           China  CHN  1.371220e+09     8027.683810
# 84           India  IND  1.311051e+09     1598.259034
# 191  United States  USA  3.214188e+08    56115.718426
# 85       Indonesia  INA  2.575638e+08     3346.487039
# 26          Brazil  BRA  2.078475e+08     8538.589975

# %%
population_ascending = population_ascending.reset_index(drop = True)
display(population_ascending.head(5))
population_ascending.at[0,'Country']
# Out:
#                   Country Code  Population  GDP per Capita
# 0                   Nauru  NRU     10222.0     9827.544281
# 1                   Palau  PLW     21291.0    13498.661406
# 2  British Virgin Islands  IVB     30117.0             NaN
# 3              San Marino  SMR     31781.0             NaN
# 4           Liechtenstein  LIE     37531.0             NaN
# 'Nauru'

# %%
population_descending = population_descending.reset_index(drop = True)
display(population_descending.head(5))
population_descending.at[0,'Country']
# Out:
#          Country Code    Population  GDP per Capita
# 0          China  CHN  1.371220e+09     8027.683810
# 1          India  IND  1.311051e+09     1598.259034
# 2  United States  USA  3.214188e+08    56115.718426
# 3      Indonesia  INA  2.575638e+08     3346.487039
# 4         Brazil  BRA  2.078475e+08     8538.589975
# 'China'

# %% [markdown]
# The index has been re-arranged

# %% [markdown]
# 6) Grouping time! Remember the group and aggregate paradigm for these tasks.
#
# Let's use the winter olympics DataFrame this time. Can you display:
#
# >a) The number of medals for each country? (hint: use `.groupby` and then `.count`)
#
# >b) The number of medals for each sport. Treat Mens and Womens categories as separate sports? (Hint: groupby can take a list of column names)
#
# >c) The Average number of medals in a year they competed for each country? This one requires two groupby statements. First, groupby two columns and aggregate. Then use groupby on that output to compute an average.

# %%
winter_medals_country = winter_df.groupby('Country').count()['Medal']
display(winter_medals_country)
# Out:
# Country
# AUS     15
# AUT    280
# BEL     13
# BLR     15
# BUL      6
# CAN    625
# CHN     82
# CRO     11
# CZE     75
# DEN      5
# ESP      2
# EST      7
# EUA     21
# EUN     60
# FIN    434
# FRA    152
# FRG     94
# GBR     79
# GDR    162
# GER    360
# HUN     12
# ITA    192
# JPN     63
# KAZ      7
# KOR     87
# LAT     15
# LIE      9
# LUX      2
# NED    122
# NOR    457
# NZL      1
# POL     27
# PRK      2
# ROU      2
# RUS    263
# SLO     18
# SUI    285
# SVK      5
# SWE    433
# TCH    158
# UKR     11
# URS    440
# USA    653
# UZB      1
# YUG      7
# Name: Medal, dtype: int64

# %%
winter_medals_gender = winter_df.groupby(['Gender', 'Sport']).count()['Medal']
display(winter_medals_gender)
# Out:
# Gender  Sport
# Men     Biathlon       270
#         Bobsleigh      416
#         Curling         97
#         Ice Hockey    1231
#         Luge           135
#         Skating        665
#         Skiing        1130
# Women   Biathlon       150
#         Bobsleigh       36
#         Curling         75
#         Ice Hockey     305
#         Luge            45
#         Skating        564
#         Skiing         651
# Name: Medal, dtype: int64

# %%
winter_country_year =winter_df.groupby(['Country','Year']).count()

winter_country_year_medal = winter_country_year.groupby('Country').aggregate('mean')['Medal']

display(winter_country_year_medal)
# Out:
# Country
# AUS     2.500000
# AUT    12.727273
# BEL     3.250000
# BLR     2.500000
# BUL     1.500000
# CAN    28.409091
# CHN    11.714286
# CRO     2.750000
# CZE    15.000000
# DEN     5.000000
# ESP     1.000000
# EST     2.333333
# EUA     7.000000
# EUN    60.000000
# FIN    19.727273
# FRA     7.238095
# FRG    13.428571
# GBR     5.266667
# GDR    27.000000
# GER    36.000000
# HUN     2.000000
# ITA    10.666667
# JPN     5.250000
# KAZ     1.750000
# KOR    12.428571
# LAT     5.000000
# LIE     2.250000
# LUX     2.000000
# NED     8.133333
# NOR    20.772727
# NZL     1.000000
# POL     3.857143
# PRK     1.000000
# ROU     2.000000
# RUS    43.833333
# SLO     4.500000
# SUI    13.571429
# SVK     1.666667
# SWE    19.681818
# TCH    14.363636
# UKR     2.750000
# URS    48.888889
# USA    29.681818
# UZB     1.000000
# YUG     3.500000
# Name: Medal, dtype: float64

# %% [markdown]
# 7) value_counts() is a method that can be used on a Series (individual column) to quickly summarize the contents. It is similar to calling groupby, count and then sort_values. I want to show how this method works and some tricks you can use with it. We are going to use the winter olmpics DataFrame again.
#
# >a) Use .value_counts() on the Sport column to see what Sports exist and how many medals have been won in each sport. Save the output to a variable.
#
# >b) Notice that the output of value_counts is a Series where the values are the counts and the indices are the labels. Display the largest value in the Series you produced in a). (Hint: use .iat)
#
# >c) How many medals have been won in the "Skating" sport? (hint: sport names are the indices of the series so you can access them directly with the [] operator)
#
# >d) Sometimes it can be easier to work with data as a DataFrame than a Series (e.g. using the loc operator). Use .reset_index() on your Series to turn the value_counts() series into a DataFrame.

# %%
sport_value_count = winter_df.value_counts('Sport')
display(sport_value_count)
# Out:
# Sport
# Skiing        1781
# Ice Hockey    1536
# Skating       1229
# Bobsleigh      452
# Biathlon       420
# Luge           180
# Curling        172
# dtype: int64

# %%
sport_value_count.iat[0]
# Out:
# 1781

# %%
sport_value_count['Skating']
# Out:
# 1229

# %%
sport_value_count.reset_index()
# Out:
#         Sport     0
# 0      Skiing  1781
# 1  Ice Hockey  1536
# 2     Skating  1229
# 3   Bobsleigh   452
# 4    Biathlon   420
# 5        Luge   180
# 6     Curling   172

# %% [markdown]
# 8) Joins. The country dict is a great example of where you can use a join to connect two DataFrames. Our goal for this question is to join the winter olympics DataFrame with the country dictionary so that every row in the winter olympics dataframe also contains the Country name (not just the country code), Population, and GDP per Capita:
#
# >a) Use set_index() on the country dictionary DataFrame and set the index to be the country code.
#
# >b) Call .join using the winter olympics DataFrame. The tricky part is deciding what the arguments should be. The first argument should be the DataFrame from a). The join should be done on the "Country" column. Give informative suffix values for lsuffix and rsuffix so that there isn't name conflicts. You decide what value should be used for "how" so that each row corresponds to a row in the winter olympics DataFrame.

# %%
country_dict_df_indexed = country_dict_df.set_index('Code')
display(country_dict_df_indexed)
# Out:
#               Country  Population  GDP per Capita
# Code
# AFG       Afghanistan  32526562.0      594.323081
# ALB           Albania   2889167.0     3945.217582
# ALG           Algeria  39666519.0     4206.031232
# ASA   American Samoa*     55538.0             NaN
# AND           Andorra     70473.0             NaN
# ...               ...         ...             ...
# VIE           Vietnam  91703800.0     2111.138024
# ISV   Virgin Islands*    103574.0             NaN
# YEM             Yemen  26832215.0     1406.291651
# ZAM            Zambia  16211767.0     1304.879014
# ZIM          Zimbabwe  15602751.0      924.143819
#
# [201 rows x 3 columns]

# %%
winter_df
# Out:
#       Year      City     Sport  ... Gender            Event   Medal
# 0     1924  Chamonix  Biathlon  ...    Men  Military Patrol  Bronze
# 1     1924  Chamonix  Biathlon  ...    Men  Military Patrol  Bronze
# 2     1924  Chamonix  Biathlon  ...    Men  Military Patrol  Bronze
# 3     1924  Chamonix  Biathlon  ...    Men  Military Patrol  Bronze
# 4     1924  Chamonix  Biathlon  ...    Men  Military Patrol    Gold
# ...    ...       ...       ...  ...    ...              ...     ...
# 5765  2014     Sochi    Skiing  ...  Women       Slopestyle  Bronze
# 5766  2014     Sochi    Skiing  ...  Women       Slopestyle    Gold
# 5767  2014     Sochi    Skiing  ...  Women  Snowboard Cross  Silver
# 5768  2014     Sochi    Skiing  ...  Women  Snowboard Cross    Gold
# 5769  2014     Sochi    Skiing  ...  Women  Snowboard Cross  Bronze
#
# [5770 rows x 9 columns]

# %%
winter_df.join(country_dict_df_indexed,on = 'Country', how = "left", lsuffix = '_code', rsuffix= '_name')
# Out:
#       Year      City     Sport  ...    Country_name   Population GDP per Capita
# 0     1924  Chamonix  Biathlon  ...          France   66808385.0   36205.568102
# 1     1924  Chamonix  Biathlon  ...          France   66808385.0   36205.568102
# 2     1924  Chamonix  Biathlon  ...          France   66808385.0   36205.568102
# 3     1924  Chamonix  Biathlon  ...          France   66808385.0   36205.568102
# 4     1924  Chamonix  Biathlon  ...     Switzerland    8286976.0   80945.079219
# ...    ...       ...       ...  ...             ...          ...            ...
# 5765  2014     Sochi    Skiing  ...  United Kingdom   65138232.0   43875.969614
# 5766  2014     Sochi    Skiing  ...   United States  321418820.0   56115.718426
# 5767  2014     Sochi    Skiing  ...          Canada   35851774.0   43248.529909
# 5768  2014     Sochi    Skiing  ...  Czech Republic   10551219.0   17548.338213
# 5769  2014     Sochi    Skiing  ...          France   66808385.0   36205.568102
#
# [5770 rows x 12 columns]

# %% [markdown]
# 9) Apply. The apply method can be very powerful as it allows you to modify or create columns with arbitrary functions. Let's make a new column in the winter olympics DataFrame that contains the Athlete's last name only. Follow these steps:
# >a) Write a function that takes a string in the format "x, y" and returns the "x" portion. You can use the .split string method to accomplish this.
#
# >b) Call .apply on the Athlete column and give your function you wrote in a) as the argument. Assign the output to a new column named "athlete_last_name".

# %%
def extract_Last_Name(full_name):
  last_name = full_name.split()[0][:-1]
  return last_name

# %%
winter_df_last_name = winter_df
winter_df_last_name['athlete_last_name'] = winter_df['Athlete'].apply(extract_Last_Name)
display(winter_df_last_name)
# Out:
#       Year      City     Sport  ...            Event   Medal athlete_last_name
# 0     1924  Chamonix  Biathlon  ...  Military Patrol  Bronze           BERTHET
# 1     1924  Chamonix  Biathlon  ...  Military Patrol  Bronze        MANDRILLON
# 2     1924  Chamonix  Biathlon  ...  Military Patrol  Bronze        MANDRILLON
# 3     1924  Chamonix  Biathlon  ...  Military Patrol  Bronze          VANDELLE
# 4     1924  Chamonix  Biathlon  ...  Military Patrol    Gold     AUFDENBLATTEN
# ...    ...       ...       ...  ...              ...     ...               ...
# 5765  2014     Sochi    Skiing  ...       Slopestyle  Bronze             JONES
# 5766  2014     Sochi    Skiing  ...       Slopestyle    Gold          ANDERSON
# 5767  2014     Sochi    Skiing  ...  Snowboard Cross  Silver           MALTAIS
# 5768  2014     Sochi    Skiing  ...  Snowboard Cross    Gold           SAMKOVA
# 5769  2014     Sochi    Skiing  ...  Snowboard Cross  Bronze         TRESPEUCH
#
# [5770 rows x 10 columns]

# %% [markdown]
# ## Advanced Questions

# %% [markdown]
# 1) What country has the most medals in the summer olympics overall? Please return the name of the country. Your code should do look up the name of the country from the country codes dictionary.

# %%
country_medal_count = summer_df.value_counts('Country').reset_index()
country_medal_count = country_medal_count.join(country_dict_df_indexed, on = 'Country', how = 'left', lsuffix = '_code', rsuffix = '_name')
country_medal_count.iat[0,2]
# Out:
# 'United States'

# %% [markdown]
# For each country, what sport have they won the most Gold medals in? Consider
#  * 2) Just the summer olympics.
#  * 3) Just the winter olympics.
#  * 4) Both the summer and winter olympics.
#
# Some bonus goals:
#
# *   Think about how to organize your code to avoid repetition
# *   Display the results with informative column names
# *   Use full names of the countries
# *   Ignore countries that are not in the country codes dictionary

# %%
def finding_most_gold(df, type_of_medal = 'Gold', country_df = country_dict_df_indexed):
  df = df[df['Medal']== type_of_medal]
  df = df.value_counts(['Country','Sport','Medal']).reset_index()
  df = df.groupby('Country').max()
  df = df.rename(columns = {0:'Count of Medals'})
  if isinstance(country_df, pd.DataFrame):
    df = df.join(country_dict_df_indexed,on = 'Country', how = "inner", lsuffix = '_code', rsuffix= '_name')
  
  return df

# %%
if isinstance(summer_df,pd.DataFrame):
  print('Yes')
else:
  print('No')
# Out:
# Yes

# %%
finding_most_gold(summer_df,'Gold')
# Out:
#                  Sport Medal  ...    Population GDP per Capita
# Country                       ...
# ALG             Boxing  Gold  ...  3.966652e+07    4206.031232
# ARG          Taekwondo  Gold  ...  4.341676e+07   13431.878340
# ARM          Wrestling  Gold  ...  3.017712e+06    3489.127690
# AUS      Weightlifting  Gold  ...  2.378117e+07   56310.962993
# AUT      Weightlifting  Gold  ...  8.611088e+06   43774.985174
# AZE          Wrestling  Gold  ...  9.651349e+06    5496.344640
# BAH            Sailing  Gold  ...  3.880190e+05   22817.230857
# BDI          Athletics  Gold  ...  1.117892e+07     277.068309
# BEL      Weightlifting  Gold  ...  1.128572e+07   40324.027766
# BLR      Weightlifting  Gold  ...  9.513000e+06    5740.456495
# BRA         Volleyball  Gold  ...  2.078475e+08    8538.589975
# BUL          Wrestling  Gold  ...  7.177991e+06    6993.477360
# CAN          Wrestling  Gold  ...  3.585177e+07   43248.529909
# CHI             Tennis  Gold  ...  1.794814e+07   13416.230039
# CHN          Wrestling  Gold  ...  1.371220e+09    8027.683810
# CMR           Football  Gold  ...  2.334418e+07    1217.260670
# COL      Weightlifting  Gold  ...  4.822870e+07    6056.147717
# CRC           Aquatics  Gold  ...  4.807850e+06   11260.092160
# CRO      Weightlifting  Gold  ...  4.224404e+06   11535.829356
# CUB          Wrestling  Gold  ...  1.138956e+07            NaN
# CZE           Shooting  Gold  ...  1.055122e+07   17548.338213
# DEN      Weightlifting  Gold  ...  5.676002e+06   51989.293471
# DOM             Boxing  Gold  ...  1.052839e+07    6468.473492
# ECU          Athletics  Gold  ...  1.614436e+07    6205.064145
# EGY          Wrestling  Gold  ...  9.150808e+07    3614.746766
# ESP      Weightlifting  Gold  ...  4.641827e+07   25831.582305
# EST          Wrestling  Gold  ...  1.311998e+06   17118.504200
# ETH          Athletics  Gold  ...  9.939075e+07     619.169406
# FIN          Wrestling  Gold  ...  5.482013e+06   42311.036231
# FRA          Wrestling  Gold  ...  6.680838e+07   36205.568102
# GBR          Wrestling  Gold  ...  6.513823e+07   43875.969614
# GEO          Wrestling  Gold  ...  3.679000e+06    3795.973308
# GER          Wrestling  Gold  ...  8.141314e+07   41313.313995
# GRE          Wrestling  Gold  ...  1.082373e+07   18002.230578
# GRN          Athletics  Gold  ...  1.068250e+05    9212.020352
# HKG            Sailing  Gold  ...  7.305700e+06   42327.839957
# HUN          Wrestling  Gold  ...  9.844686e+06   12363.543460
# INA          Badminton  Gold  ...  2.575638e+08    3346.487039
# IND           Shooting  Gold  ...  1.311051e+09    1598.259034
# IRI          Wrestling  Gold  ...  7.910927e+07            NaN
# IRL             Boxing  Gold  ...  4.640703e+06   61133.672427
# ISR            Sailing  Gold  ...  8.380400e+06   35728.093495
# ITA          Wrestling  Gold  ...  6.080208e+07   29957.804315
# JAM          Athletics  Gold  ...  2.725941e+06    5232.024583
# JPN          Wrestling  Gold  ...  1.269585e+08   32477.215145
# KAZ          Wrestling  Gold  ...  1.754413e+07   10509.981070
# KEN             Boxing  Gold  ...  4.605030e+07    1376.712829
# KOR          Wrestling  Gold  ...  5.061704e+07   27221.524051
# LAT         Gymnastics  Gold  ...  1.978440e+06   13648.547556
# LTU           Shooting  Gold  ...  2.910199e+06   14147.049379
# LUX          Athletics  Gold  ...  5.696760e+05  101449.968168
# MAR          Athletics  Gold  ...  3.437751e+07    2878.201342
# MEX      Weightlifting  Gold  ...  1.270172e+08    9005.024265
# MGL               Judo  Gold  ...  2.959134e+06    3967.829386
# MOZ          Athletics  Gold  ...  2.797786e+07     529.242556
# NED         Volleyball  Gold  ...  1.693652e+07   44299.768085
# NGR           Football  Gold  ...  1.822020e+08    2640.290739
# NOR          Wrestling  Gold  ...  5.195921e+06   74400.369777
# NZL          Triathlon  Gold  ...  4.595700e+06   37807.967276
# PAK             Hockey  Gold  ...  1.889249e+08    1434.696665
# PAN          Athletics  Gold  ...  3.929141e+06   13268.113755
# PER           Shooting  Gold  ...  3.137667e+07    6027.125855
# POL          Wrestling  Gold  ...  3.799949e+07   12554.547554
# POR          Athletics  Gold  ...  1.034865e+07   19222.150076
# PRK          Wrestling  Gold  ...  2.515532e+07            NaN
# RSA             Tennis  Gold  ...  5.495692e+07    5723.973357
# RUS          Wrestling  Gold  ...  1.440968e+08    9092.580536
# SLO           Shooting  Gold  ...  2.063768e+06   20726.539886
# SUI          Wrestling  Gold  ...  8.286976e+06   80945.079219
# SUR           Aquatics  Gold  ...  5.429750e+05    9485.319244
# SVK      Canoe / Kayak  Gold  ...  5.424050e+06   16088.277587
# SWE          Wrestling  Gold  ...  9.798871e+06   50579.673649
# SYR          Athletics  Gold  ...  1.850241e+07            NaN
# THA      Weightlifting  Gold  ...  6.795936e+07    5814.769764
# TPE      Weightlifting  Gold  ...           NaN            NaN
# TRI          Athletics  Gold  ...  1.360088e+06   17321.884675
# TUN          Athletics  Gold  ...  1.110780e+07    3872.512084
# TUR          Wrestling  Gold  ...  7.866583e+07    9125.687590
# UAE           Shooting  Gold  ...  9.156963e+06   40438.762934
# UGA          Athletics  Gold  ...  3.903238e+07     705.292570
# UKR          Wrestling  Gold  ...  4.519820e+07    2114.954716
# URU           Football  Gold  ...  3.431555e+06   15573.900919
# USA          Wrestling  Gold  ...  3.214188e+08   56115.718426
# UZB          Wrestling  Gold  ...  3.129950e+07    2132.070368
# VEN            Fencing  Gold  ...  3.110808e+07            NaN
# ZIM             Hockey  Gold  ...  1.560275e+07     924.143819
#
# [86 rows x 6 columns]

# %%
finding_most_gold(winter_df)
# Out:
#             Sport Medal  ...    Population GDP per Capita
# Country                  ...
# AUS        Skiing  Gold  ...  2.378117e+07   56310.962993
# AUT        Skiing  Gold  ...  8.611088e+06   43774.985174
# BEL       Skating  Gold  ...  1.128572e+07   40324.027766
# BLR        Skiing  Gold  ...  9.513000e+06    5740.456495
# BUL      Biathlon  Gold  ...  7.177991e+06    6993.477360
# CAN        Skiing  Gold  ...  3.585177e+07   43248.529909
# CHN        Skiing  Gold  ...  1.371220e+09    8027.683810
# CRO        Skiing  Gold  ...  4.224404e+06   11535.829356
# CZE        Skiing  Gold  ...  1.055122e+07   17548.338213
# ESP        Skiing  Gold  ...  4.641827e+07   25831.582305
# EST        Skiing  Gold  ...  1.311998e+06   17118.504200
# FIN        Skiing  Gold  ...  5.482013e+06   42311.036231
# FRA        Skiing  Gold  ...  6.680838e+07   36205.568102
# GBR       Skating  Gold  ...  6.513823e+07   43875.969614
# GER        Skiing  Gold  ...  8.141314e+07   41313.313995
# ITA        Skiing  Gold  ...  6.080208e+07   29957.804315
# JPN        Skiing  Gold  ...  1.269585e+08   32477.215145
# KAZ        Skiing  Gold  ...  1.754413e+07   10509.981070
# KOR       Skating  Gold  ...  5.061704e+07   27221.524051
# LIE        Skiing  Gold  ...  3.753100e+04            NaN
# NED        Skiing  Gold  ...  1.693652e+07   44299.768085
# NOR        Skiing  Gold  ...  5.195921e+06   74400.369777
# POL        Skiing  Gold  ...  3.799949e+07   12554.547554
# RUS        Skiing  Gold  ...  1.440968e+08    9092.580536
# SLO        Skiing  Gold  ...  2.063768e+06   20726.539886
# SUI        Skiing  Gold  ...  8.286976e+06   80945.079219
# SVK      Biathlon  Gold  ...  5.424050e+06   16088.277587
# SWE        Skiing  Gold  ...  9.798871e+06   50579.673649
# UKR       Skating  Gold  ...  4.519820e+07    2114.954716
# USA        Skiing  Gold  ...  3.214188e+08   56115.718426
# UZB        Skiing  Gold  ...  3.129950e+07    2132.070368
#
# [31 rows x 6 columns]

# %%
finding_most_gold(summer_df.append(winter_df).reset_index())
# Out:
#                  Sport Medal  ...    Population GDP per Capita
# Country                       ...
# ALG             Boxing  Gold  ...  3.966652e+07    4206.031232
# ARG          Taekwondo  Gold  ...  4.341676e+07   13431.878340
# ARM          Wrestling  Gold  ...  3.017712e+06    3489.127690
# AUS      Weightlifting  Gold  ...  2.378117e+07   56310.962993
# AUT      Weightlifting  Gold  ...  8.611088e+06   43774.985174
# AZE          Wrestling  Gold  ...  9.651349e+06    5496.344640
# BAH            Sailing  Gold  ...  3.880190e+05   22817.230857
# BDI          Athletics  Gold  ...  1.117892e+07     277.068309
# BEL      Weightlifting  Gold  ...  1.128572e+07   40324.027766
# BLR      Weightlifting  Gold  ...  9.513000e+06    5740.456495
# BRA         Volleyball  Gold  ...  2.078475e+08    8538.589975
# BUL          Wrestling  Gold  ...  7.177991e+06    6993.477360
# CAN          Wrestling  Gold  ...  3.585177e+07   43248.529909
# CHI             Tennis  Gold  ...  1.794814e+07   13416.230039
# CHN          Wrestling  Gold  ...  1.371220e+09    8027.683810
# CMR           Football  Gold  ...  2.334418e+07    1217.260670
# COL      Weightlifting  Gold  ...  4.822870e+07    6056.147717
# CRC           Aquatics  Gold  ...  4.807850e+06   11260.092160
# CRO      Weightlifting  Gold  ...  4.224404e+06   11535.829356
# CUB          Wrestling  Gold  ...  1.138956e+07            NaN
# CZE             Skiing  Gold  ...  1.055122e+07   17548.338213
# DEN      Weightlifting  Gold  ...  5.676002e+06   51989.293471
# DOM             Boxing  Gold  ...  1.052839e+07    6468.473492
# ECU          Athletics  Gold  ...  1.614436e+07    6205.064145
# EGY          Wrestling  Gold  ...  9.150808e+07    3614.746766
# ESP      Weightlifting  Gold  ...  4.641827e+07   25831.582305
# EST          Wrestling  Gold  ...  1.311998e+06   17118.504200
# ETH          Athletics  Gold  ...  9.939075e+07     619.169406
# FIN          Wrestling  Gold  ...  5.482013e+06   42311.036231
# FRA          Wrestling  Gold  ...  6.680838e+07   36205.568102
# GBR          Wrestling  Gold  ...  6.513823e+07   43875.969614
# GEO          Wrestling  Gold  ...  3.679000e+06    3795.973308
# GER          Wrestling  Gold  ...  8.141314e+07   41313.313995
# GRE          Wrestling  Gold  ...  1.082373e+07   18002.230578
# GRN          Athletics  Gold  ...  1.068250e+05    9212.020352
# HKG            Sailing  Gold  ...  7.305700e+06   42327.839957
# HUN          Wrestling  Gold  ...  9.844686e+06   12363.543460
# INA          Badminton  Gold  ...  2.575638e+08    3346.487039
# IND           Shooting  Gold  ...  1.311051e+09    1598.259034
# IRI          Wrestling  Gold  ...  7.910927e+07            NaN
# IRL             Boxing  Gold  ...  4.640703e+06   61133.672427
# ISR            Sailing  Gold  ...  8.380400e+06   35728.093495
# ITA          Wrestling  Gold  ...  6.080208e+07   29957.804315
# JAM          Athletics  Gold  ...  2.725941e+06    5232.024583
# JPN          Wrestling  Gold  ...  1.269585e+08   32477.215145
# KAZ          Wrestling  Gold  ...  1.754413e+07   10509.981070
# KEN             Boxing  Gold  ...  4.605030e+07    1376.712829
# KOR          Wrestling  Gold  ...  5.061704e+07   27221.524051
# LAT         Gymnastics  Gold  ...  1.978440e+06   13648.547556
# LIE             Skiing  Gold  ...  3.753100e+04            NaN
# LTU           Shooting  Gold  ...  2.910199e+06   14147.049379
# LUX          Athletics  Gold  ...  5.696760e+05  101449.968168
# MAR          Athletics  Gold  ...  3.437751e+07    2878.201342
# MEX      Weightlifting  Gold  ...  1.270172e+08    9005.024265
# MGL               Judo  Gold  ...  2.959134e+06    3967.829386
# MOZ          Athletics  Gold  ...  2.797786e+07     529.242556
# NED         Volleyball  Gold  ...  1.693652e+07   44299.768085
# NGR           Football  Gold  ...  1.822020e+08    2640.290739
# NOR          Wrestling  Gold  ...  5.195921e+06   74400.369777
# NZL          Triathlon  Gold  ...  4.595700e+06   37807.967276
# PAK             Hockey  Gold  ...  1.889249e+08    1434.696665
# PAN          Athletics  Gold  ...  3.929141e+06   13268.113755
# PER           Shooting  Gold  ...  3.137667e+07    6027.125855
# POL          Wrestling  Gold  ...  3.799949e+07   12554.547554
# POR          Athletics  Gold  ...  1.034865e+07   19222.150076
# PRK          Wrestling  Gold  ...  2.515532e+07            NaN
# RSA             Tennis  Gold  ...  5.495692e+07    5723.973357
# RUS          Wrestling  Gold  ...  1.440968e+08    9092.580536
# SLO             Skiing  Gold  ...  2.063768e+06   20726.539886
# SUI          Wrestling  Gold  ...  8.286976e+06   80945.079219
# SUR           Aquatics  Gold  ...  5.429750e+05    9485.319244
# SVK      Canoe / Kayak  Gold  ...  5.424050e+06   16088.277587
# SWE          Wrestling  Gold  ...  9.798871e+06   50579.673649
# SYR          Athletics  Gold  ...  1.850241e+07            NaN
# THA      Weightlifting  Gold  ...  6.795936e+07    5814.769764
# TPE      Weightlifting  Gold  ...           NaN            NaN
# TRI          Athletics  Gold  ...  1.360088e+06   17321.884675
# TUN          Athletics  Gold  ...  1.110780e+07    3872.512084
# TUR          Wrestling  Gold  ...  7.866583e+07    9125.687590
# UAE           Shooting  Gold  ...  9.156963e+06   40438.762934
# UGA          Athletics  Gold  ...  3.903238e+07     705.292570
# UKR          Wrestling  Gold  ...  4.519820e+07    2114.954716
# URU           Football  Gold  ...  3.431555e+06   15573.900919
# USA          Wrestling  Gold  ...  3.214188e+08   56115.718426
# UZB          Wrestling  Gold  ...  3.129950e+07    2132.070368
# VEN            Fencing  Gold  ...  3.110808e+07            NaN
# ZIM             Hockey  Gold  ...  1.560275e+07     924.143819
#
# [87 rows x 6 columns]

# %% [markdown]
# 5) For each country, what is the average medal count for each gender? The average should be across years. This time report the average taking both summer and winter olympics into account.

# %% [markdown]
# 6) Get the top 5 athletes in terms of how many separate olympics they have appeared at? (NOT the most medals). Use both the winter and summer olympics. Treat the winter and summer olympics as separate olympics.

# %% [markdown]
# Optional: 7) Come up with your own analytical question. What interesting things can you ask the data? Use pandas to answer the question. If possible, elaborate how the answer could be used.
